# %% [markdown]
# # DermaXplain - Data Preprocessing Notebook
#
# This notebook defines the **extra preprocessing pipeline** for DermaXplain.
#
# ## Objectives
#
#
# - lesion-centered cropping
# - hair removal
# - color normalisation
# - export variants
